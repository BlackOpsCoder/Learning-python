# %%
import numpy as np
import time

# %%
numpy_array = np.array([1, 2, 3, 4, 5])
print("Numpy Array: ", numpy_array)
print("Type: ", type(numpy_array))
numpy_array2 = numpy_array + 10
print("Numpy Array 2: ", numpy_array2)
# Out:
# Numpy Array:  [1 2 3 4 5]
# Type:  <class 'numpy.ndarray'>
# Numpy Array 2:  [11 12 13 14 15]

# %%
python_array = list(range(1000000))
numpy_array = np.arange(1000000)
start = time.time()
result_numpy = numpy_array + 1
numpy_time = time.time() - start
start = time.time()
result_python = [x + 1 for x in python_array]
python_time = time.time() - start
print("Python Time:", python_time)
print("Numpy Time:", numpy_time)
print("Numpy is ", ((python_time / numpy_time) * 100), "'%' faster!")
# Out:
# Python Time: 0.027228116989135742
# Numpy Time: 0.0005631446838378906
# Numpy is  4835.012701100763 '%' faster!

# %%
a = np.array([1, 2, 3, 4, 5])
b = np.array([6, 7, 8, 9, 10])

print(np.sqrt(a))
# Out:
# [1.         1.41421356 1.73205081 2.         2.23606798]
